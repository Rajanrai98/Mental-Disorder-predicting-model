# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn

# %%
data = pd.read_csv(r"C:\Users\user\Downloads\Dataset-Mental-Disorders.csv")

# %%
data
# Out:
#     Patient Number     Sadness    Euphoric  Exhausted Sleep dissorder  \
# 0       Patiant-01     Usually      Seldom  Sometimes       Sometimes
# 1       Patiant-02     Usually      Seldom    Usually       Sometimes
# 2       Patiant-03   Sometimes  Most-Often  Sometimes       Sometimes
# 3       Patiant-04     Usually      Seldom    Usually      Most-Often
# 4       Patiant-05     Usually     Usually  Sometimes       Sometimes
# ..             ...         ...         ...        ...             ...
# 115    Patiant-116  Most-Often      Seldom    Usually       Sometimes
# 116    Patiant-117   Sometimes   Sometimes  Sometimes          Seldom
# 117    Patiant-118     Usually   Sometimes    Usually       Sometimes
# 118    Patiant-119     Usually   Sometimes     Seldom          Seldom
# 119    Patiant-120   Sometimes     Usually     Seldom         Usually
#
#     Mood Swing Suicidal thoughts Anorxia Authority Respect Try-Explanation  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Patient Number       120 non-null    object
#  1   Sadness              120 non-null    object
#  2   Euphoric             120 non-null    object
#  3   Exhausted            120 non-null    object
#  4   Sleep dissorder      120 non-null    object
#  5   Mood Swing           120 non-null    object
#  6   Suicidal thoughts    120 non-null    object
#  7   Anorxia              120 non-null    object
#  8   Authority Respect    120 non-null    object
#  9   Try-Explanation      120 non-null    object
#  10  Aggressive Response  120 non-null    object
#  11  Ignore & Move-On     120 non-null    object
#  12  Nervous Break-down   120 non-null    object
#  13  Admit Mistakes       120 non-null    object
#  14  Overthinking         120 non-null    object
# ...

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score , classification_report,confusion_matrix
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
le = LabelEncoder()

# %%
data = data.apply(le.fit_transform)

# %%
data
# Out:
#      Patient Number  Sadness  Euphoric  Exhausted  Sleep dissorder  \
# 0                 0        3         1          2                2
# 1                 1        3         1          3                2
# 2                 2        2         0          2                2
# 3                 3        3         1          3                0
# 4                 4        3         3          2                2
# ..              ...      ...       ...        ...              ...
# 115              27        0         1          3                2
# 116              28        2         2          2                1
# 117              29        3         2          3                2
# 118              30        3         2          1                1
# 119              32        2         3          1                3
#
#      Mood Swing  Suicidal thoughts  Anorxia  Authority Respect  \
# 0             1                  2        0                  0
# ...

# %%
data.isnull().sum()
# Out:
# Patient Number         0
# Sadness                0
# Euphoric               0
# Exhausted              0
# Sleep dissorder        0
# Mood Swing             0
# Suicidal thoughts      0
# Anorxia                0
# Authority Respect      0
# Try-Explanation        0
# Aggressive Response    0
# Ignore & Move-On       0
# Nervous Break-down     0
# Admit Mistakes         0
# Overthinking           0
# Sexual Activity        0
# Concentration          0
# Optimisim              0
# Expert Diagnose        0
# dtype: int64

# %%
data_count = data["Expert Diagnose"].value_counts()

# %%
sn.histplot(data["Expert Diagnose"] , color = "orange")
# Out:
# <Axes: xlabel='Expert Diagnose', ylabel='Count'>

# %%
sn.countplot(x = "Expert Diagnose" , data = data )
# Out:
# <Axes: xlabel='Expert Diagnose', ylabel='count'>

# %%
data.corr()
# Out:
#                      Patient Number   Sadness  Euphoric  Exhausted  \
# Patient Number             1.000000 -0.050551 -0.025027  -0.128340
# Sadness                   -0.050551  1.000000  0.063457   0.129409
# Euphoric                  -0.025027  0.063457  1.000000   0.059355
# Exhausted                 -0.128340  0.129409  0.059355   1.000000
# Sleep dissorder            0.023741  0.131310  0.041017   0.079247
# Mood Swing                 0.005540  0.072792 -0.061155  -0.074675
# Suicidal thoughts         -0.090891 -0.094410 -0.109432   0.003778
# Anorxia                   -0.069272 -0.090575 -0.043226  -0.047122
# Authority Respect          0.087974 -0.088349  0.085438   0.063414
# Try-Explanation           -0.185231  0.025829  0.076937   0.071747
# Aggressive Response        0.173307  0.058923  0.084112  -0.069258
# Ignore & Move-On           0.034158 -0.208775 -0.093250   0.004944
# Nervous Break-down         0.040920 -0.152782 -0.123539  -0.150222
# ...

# %%
plt.figure(figsize = (24,12))
sn.heatmap(data.corr() , cmap = "tab20" , annot = True)
# Out:
# <Axes: >

# %%
data.describe()
# Out:
#        Patient Number     Sadness    Euphoric   Exhausted  Sleep dissorder  \
# count      120.000000  120.000000  120.000000  120.000000       120.000000
# mean        59.500000    1.883333    1.633333    1.633333         1.758333
# std         34.785054    1.070485    0.849452    1.144467         1.053173
# min          0.000000    0.000000    0.000000    0.000000         0.000000
# 25%         29.750000    1.000000    1.000000    0.750000         1.000000
# 50%         59.500000    2.000000    2.000000    2.000000         2.000000
# 75%         89.250000    3.000000    2.000000    3.000000         3.000000
# max        119.000000    3.000000    3.000000    3.000000         3.000000
#
#        Mood Swing  Suicidal thoughts     Anorxia  Authority Respect  \
# count  120.000000         120.000000  120.000000         120.000000
# mean     0.475000           0.483333    0.383333           0.391667
# std      0.501468           0.518293    0.488237           0.490169
# ...

# %%
data.head()
# Out:
#    Patient Number  Sadness  Euphoric  Exhausted  Sleep dissorder  Mood Swing  \
# 0               0        3         1          2                2           1
# 1               1        3         1          3                2           0
# 2               2        2         0          2                2           1
# 3               3        3         1          3                0           1
# 4               4        3         3          2                2           0
#
#    Suicidal thoughts  Anorxia  Authority Respect  Try-Explanation  \
# 0                  2        0                  0                1
# 1                  1        0                  0                0
# 2                  0        0                  0                1
# 3                  1        1                  0                1
# 4                  0        0                  0                0
#
#    Aggressive Response  Ignore & Move-On  Nervous Break-down  Admit Mistakes  \
# ...

# %%
data.skew()
# Out:
# Patient Number         0.000000
# Sadness               -0.599678
# Euphoric               0.033028
# Exhausted             -0.265839
# Sleep dissorder       -0.421472
# Mood Swing             0.101397
# Suicidal thoughts      0.251590
# Anorxia                0.486010
# Authority Respect      0.449516
# Try-Explanation        0.101397
# Aggressive Response    0.067551
# Ignore & Move-On       0.342356
# Nervous Break-down    -0.067551
# Admit Mistakes         0.033761
# Overthinking          -0.169373
# Sexual Activity        0.115509
# Concentration          0.190913
# Optimisim              0.183114
# Expert Diagnose       -0.026408
# dtype: float64

# %%
sn.pairplot(data , hue = "Expert Diagnose")

# %%
sn.jointplot(x = "Sleep dissorder" , y = "Expert Diagnose" , data = data)

# %%
x = data.drop(["Expert Diagnose"] , axis = 1)
y = data["Expert Diagnose"]

# %%
x_train , x_test , y_train , y_test = train_test_split(x , y , test_size = 0.20 , random_state = 42)

# %%
x_train.shape , x_test.shape
# Out:
# ((96, 18), (24, 18))

# %%
model = DecisionTreeClassifier(criterion = "entropy" , max_depth = 3)

# %%
model.fit(x_train , y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3)

# %%
y_pred = model.predict(x_test)

# %%
y_pred
# Out:
# array([2, 0, 3, 2, 2, 2, 3, 3, 2, 2, 2, 0, 0, 1, 3, 1, 2, 1, 3, 1, 2, 1,
#        2, 2])

# %%
pd.DataFrame({"y_test":y_test , "y_pred":y_pred})
# Out:
#      y_test  y_pred
# 44        2       2
# 47        1       0
# 4         3       3
# 55        3       2
# 26        3       2
# 64        3       2
# 73        3       3
# 10        3       3
# 40        2       2
# 107       2       2
# 18        2       2
# 62        0       0
# 11        0       0
# 36        0       1
# 89        3       3
# 91        1       1
# 109       2       2
# 0         1       1
# 88        0       3
# 104       1       1
# 65        2       2
# 45        1       1
# 31        2       2
# 70        2       2

# %%
accuracy_tree = accuracy_score(y_test , y_pred)
print(accuracy_tree)
# Out:
# 0.75

# %%
classification_result = classification_report(y_test , y_pred)
print(classification_result)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.50      0.57         4
#            1       0.80      0.80      0.80         5
#            2       0.73      1.00      0.84         8
#            3       0.80      0.57      0.67         7
#
#     accuracy                           0.75        24
#    macro avg       0.75      0.72      0.72        24
# weighted avg       0.75      0.75      0.74        24

# %%
model_random = RandomForestClassifier(n_estimators = 100 , max_features = 5)
model_random.fit(x_train , y_train)
# Out:
# RandomForestClassifier(max_features=5)

# %%
y_random_pred = model_random.predict(x_test)
y_random_pred
# Out:
# array([2, 1, 3, 2, 2, 3, 3, 3, 2, 0, 2, 0, 0, 0, 3, 1, 2, 1, 3, 1, 2, 1,
#        2, 2])

# %%
pd.DataFrame({"y_test":y_test , "y_random_pred":y_random_pred})
# Out:
#      y_test  y_random_pred
# 44        2              2
# 47        1              1
# 4         3              3
# 55        3              2
# 26        3              2
# 64        3              3
# 73        3              3
# 10        3              3
# 40        2              2
# 107       2              0
# 18        2              2
# 62        0              0
# 11        0              0
# 36        0              0
# 89        3              3
# 91        1              1
# 109       2              2
# 0         1              1
# 88        0              3
# 104       1              1
# 65        2              2
# 45        1              1
# 31        2              2
# 70        2              2

# %%
accuracy_result = accuracy_score(y_test , y_random_pred)

# %%
accuracy_result
# Out:
# 0.8333333333333334

# %%
from sklearn.ensemble import BaggingClassifier

# %%
model_bagging = BaggingClassifier(model_random ,n_estimators = 10, random_state = 42 )

# %%
model_bagging.fit(x_train , y_train)
# Out:
# BaggingClassifier(estimator=RandomForestClassifier(max_features=5),
#                   random_state=42)

# %%
y_pred_bagging = model_bagging.predict(x_test)

# %%
y_pred_bagging
# Out:
# array([2, 0, 3, 2, 2, 3, 3, 3, 2, 0, 2, 0, 0, 0, 3, 1, 2, 1, 3, 1, 2, 1,
#        2, 2])

# %%
pd.DataFrame({"y_test":y_test , "y_pred":y_pred_bagging})
# Out:
#      y_test  y_pred
# 44        2       2
# 47        1       0
# 4         3       3
# 55        3       2
# 26        3       2
# 64        3       3
# 73        3       3
# 10        3       3
# 40        2       2
# 107       2       0
# 18        2       2
# 62        0       0
# 11        0       0
# 36        0       0
# 89        3       3
# 91        1       1
# 109       2       2
# 0         1       1
# 88        0       3
# 104       1       1
# 65        2       2
# 45        1       1
# 31        2       2
# 70        2       2

# %%
accuracy_bagging = accuracy_score(y_test , y_pred_bagging)

# %%
accuracy_bagging
# Out:
# 0.7916666666666666
